# %%
from google.cloud import aiplatform
import joblib

# %%
aiplatform.init(project='project-eaa010ce-98d6-49ee-ab7', location='asia-southeast1')
endpoint = aiplatform.Endpoint(
    endpoint_name = '4895203887742451712'
    ) #endpoint id

print("successfully connected to endpoint")
print(f"endpoint name: ", {endpoint.resource_name})
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# Cell In[6], line 2
#       1 aiplatform.init(project='project-eaa010ce-98d6-49ee-ab7', location='asia-southeast1')
# ----> 2 endpoint = aiplatform.Endpoint(
#       3     endpoint_name = '4895203887742451712'
#       4     ) #endpoint id
#       6 print("successfully connected to endpoint")
#       7 print(f"endpoint name: ", {endpoint.resource_name})
#
# File ~\AppData\Roaming\Python\Python313\site-packages\google\cloud\aiplatform\models.py:679, in Endpoint.__init__(self, endpoint_name, project, location, credentials)
#     654 def __init__(
#     655     self,
#     656     endpoint_name: str,
#    (...)    659     credentials: Optional[auth_credentials.Credentials] = None,
#     660 ):
#     661     """Retrieves an endpoint resource.
#     662
#     663     Args:
# ...

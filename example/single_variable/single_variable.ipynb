# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt #prasthara
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('book.csv')

# %%
plt.scatter(data.videos, data.views, color='blue')
plt.xlabel('Number of Videos')
plt.ylabel('Number of Views')
# Out:
# Text(0, 0.5, 'Number of Views')

# %%
data.views
# Out:
# 0    34000
# 1    41000
# 2    42500
# 3    54300
# 4    56000
# Name: views, dtype: int64

# %%
data.videos
# Out:
# 0    30
# 1    40
# 2    50
# 3    60
# 4    70
# Name: videos, dtype: int64

# %%
x = np.array(data.videos.values)
x
# Out:
# array([30, 40, 50, 60, 70])

# %%
y = np.array(data.views.values) 
y
# Out:
# array([34000, 41000, 42500, 54300, 56000])

# %%
model = LinearRegression()
model.fit(x.reshape(-1, 1), y) #train the model
# Out:
# LinearRegression()

# %%
new_x = np.array([45]).reshape(-1, 1) 
new_x
# Out:
# array([[45]])

# %%
model.predict(new_x) # Predict views for 45 videos
# Out:
# array([42695.])

# %%
plt.scatter(data.videos, data.views, color='blue')
m,c = np.polyfit(x,y,1) 
plt.plot(x, m*x + c, color='red')

# %%
m
# Out:
# np.float64(572.9999999999999)

# %%
c
# Out:
# np.float64(16910.000000000022)

# %%
y_new = m*45 + c
y_new
# Out:
# np.float64(42695.000000000015)
